# %% [markdown]
# <a href="https://colab.research.google.com/github/MalviyaDixit19/DA/blob/main/HR_dataset_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("/content/HR Data.csv")

df.head(5)
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
df.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
# List of columns to remove
columns_to_remove = ['EmployeeCount', 'EmployeeNumber', 'StandardHours']

# Drop the unnecessary columns
df = df.drop(columns=columns_to_remove)

# %%
df.head(5)
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EnvironmentSatisfaction  \
# 0                 1          2  Life Sciences                        2
# 1                 8          1  Life Sciences                        3
# 2                 2          2          Other                        4
# 3                 3          4  Life Sciences                        4
# 4                 2          1        Medical                        1
#
#    Gender  ...  PerformanceRating  RelationshipSatisfaction  StockOptionLevel  \
# ...

# %%
# Dictionary mapping old column names to new column names
new_column_names = {
    'Age': 'Employee_Age',
    'Attrition': 'Attrition_Status',
    'BusinessTravel': 'Travel_Frequency',
    'DailyRate': 'Daily_Rate',
    'Department': 'Department_Type',
    'DistanceFromHome': 'Distance_From_Home',
    'Education': 'Education_Level',
    'EducationField': 'Education_Field',
    'EnvironmentSatisfaction': 'Environment_Satisfaction',
    # Add more column name mappings as needed
}

# Rename the columns
df = df.rename(columns=new_column_names)

# %%
df.head(5)
# Out:
#    Employee_Age Attrition_Status   Travel_Frequency  Daily_Rate  \
# 0            41              Yes      Travel_Rarely        1102
# 1            49               No  Travel_Frequently         279
# 2            37              Yes      Travel_Rarely        1373
# 3            33               No  Travel_Frequently        1392
# 4            27               No      Travel_Rarely         591
#
#           Department_Type  Distance_From_Home  Education_Level  \
# 0                   Sales                   1                2
# 1  Research & Development                   8                1
# 2  Research & Development                   2                2
# 3  Research & Development                   3                4
# 4  Research & Development                   2                1
#
#   Education_Field  Environment_Satisfaction  Gender  ...  PerformanceRating  \
# 0   Life Sciences                         2  Female  ...                  3
# ...

# %%
# Drop duplicate rows
df = df.drop_duplicates()

# %%
df.head(5)
# Out:
#    Employee_Age Attrition_Status   Travel_Frequency  Daily_Rate  \
# 0            41              Yes      Travel_Rarely        1102
# 1            49               No  Travel_Frequently         279
# 2            37              Yes      Travel_Rarely        1373
# 3            33               No  Travel_Frequently        1392
# 4            27               No      Travel_Rarely         591
#
#           Department_Type  Distance_From_Home  Education_Level  \
# 0                   Sales                   1                2
# 1  Research & Development                   8                1
# 2  Research & Development                   2                2
# 3  Research & Development                   3                4
# 4  Research & Development                   2                1
#
#   Education_Field  Environment_Satisfaction  Gender  ...  PerformanceRating  \
# 0   Life Sciences                         2  Female  ...                  3
# ...

# %%
# Sanitize specific columns
# For example, let's remove leading and trailing whitespaces from the 'BusinessTravel' column
df['Travel_Frequency'] = df['Travel_Frequency'].str.strip()

# Convert 'DailyRate' column to integer data type
df['Daily_Rate'] = df['Daily_Rate'].astype(int)

# Replace missing values in 'Education' column with the median
df['Education_Level'].fillna(df['Education_Level'].median(), inplace=True)

# %%
df.head(5)
# Out:
#    Employee_Age Attrition_Status   Travel_Frequency  Daily_Rate  \
# 0            41              Yes      Travel_Rarely        1102
# 1            49               No  Travel_Frequently         279
# 2            37              Yes      Travel_Rarely        1373
# 3            33               No  Travel_Frequently        1392
# 4            27               No      Travel_Rarely         591
#
#           Department_Type  Distance_From_Home  Education_Level  \
# 0                   Sales                   1                2
# 1  Research & Development                   8                1
# 2  Research & Development                   2                2
# 3  Research & Development                   3                4
# 4  Research & Development                   2                1
#
#   Education_Field  Environment_Satisfaction  Gender  ...  PerformanceRating  \
# 0   Life Sciences                         2  Female  ...                  3
# ...

# %%
# Define the columns you want to sanitize (remove NaN values)
columns_to_sanitize = ['Employee_Age', 'Attrition_Status', 'Travel_Frequency', 'Education_Field', 'Department_Type']

# Remove NaN values from the specified columns
df.dropna(subset=columns_to_sanitize, inplace=True)

# Display the modified DataFrame
print(df.head())
# Out:
#    Employee_Age Attrition_Status   Travel_Frequency  Daily_Rate  \
# 0            41              Yes      Travel_Rarely        1102
# 1            49               No  Travel_Frequently         279
# 2            37              Yes      Travel_Rarely        1373
# 3            33               No  Travel_Frequently        1392
# 4            27               No      Travel_Rarely         591
#
#           Department_Type  Distance_From_Home  Education_Level  \
# 0                   Sales                   1                2
# 1  Research & Development                   8                1
# 2  Research & Development                   2                2
# 3  Research & Development                   3                4
# 4  Research & Development                   2                1
#
#   Education_Field  Environment_Satisfaction  Gender  ...  PerformanceRating  \
# 0   Life Sciences                         2  Female  ...                  3
# ...

# %%
df.head()
# Out:
#    Employee_Age Attrition_Status   Travel_Frequency  Daily_Rate  \
# 0            41              Yes      Travel_Rarely        1102
# 1            49               No  Travel_Frequently         279
# 2            37              Yes      Travel_Rarely        1373
# 3            33               No  Travel_Frequently        1392
# 4            27               No      Travel_Rarely         591
#
#           Department_Type  Distance_From_Home  Education_Level  \
# 0                   Sales                   1                2
# 1  Research & Development                   8                1
# 2  Research & Development                   2                2
# 3  Research & Development                   3                4
# 4  Research & Development                   2                1
#
#   Education_Field  Environment_Satisfaction  Gender  ...  PerformanceRating  \
# 0   Life Sciences                         2  Female  ...                  3
# ...

# %%
# Impute missing values in specific columns with the median
df['Employee_Age'].fillna(df['Employee_Age'].median(), inplace=True)

# %%
df.head(5)
# Out:
#    Employee_Age Attrition_Status   Travel_Frequency  Daily_Rate  \
# 0            41              Yes      Travel_Rarely        1102
# 1            49               No  Travel_Frequently         279
# 2            37              Yes      Travel_Rarely        1373
# 3            33               No  Travel_Frequently        1392
# 4            27               No      Travel_Rarely         591
#
#           Department_Type  Distance_From_Home  Education_Level  \
# 0                   Sales                   1                2
# 1  Research & Development                   8                1
# 2  Research & Development                   2                2
# 3  Research & Development                   3                4
# 4  Research & Development                   2                1
#
#   Education_Field  Environment_Satisfaction  Gender  ...  PerformanceRating  \
# 0   Life Sciences                         2  Female  ...                  3
# ...

# %%
# Convert 'Age' column to integer data type
df['Employee_Age'] = df['Employee_Age'].astype(int)

df.head(5)
# Out:
#    Employee_Age Attrition_Status   Travel_Frequency  Daily_Rate  \
# 0            41              Yes      Travel_Rarely        1102
# 1            49               No  Travel_Frequently         279
# 2            37              Yes      Travel_Rarely        1373
# 3            33               No  Travel_Frequently        1392
# 4            27               No      Travel_Rarely         591
#
#           Department_Type  Distance_From_Home  Education_Level  \
# 0                   Sales                   1                2
# 1  Research & Development                   8                1
# 2  Research & Development                   2                2
# 3  Research & Development                   3                4
# 4  Research & Development                   2                1
#
#   Education_Field  Environment_Satisfaction  Gender  ...  PerformanceRating  \
# 0   Life Sciences                         2  Female  ...                  3
# ...

# %%
df['Employee_Age'].info()

df['Employee_Age'].describe()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 1470 entries, 0 to 1469
# Series name: Employee_Age
# Non-Null Count  Dtype
# --------------  -----
# 1470 non-null   int64
# dtypes: int64(1)
# memory usage: 11.6 KB
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:4823: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   arr.partition(
# count    1470.000000
# mean       36.940136
# std         8.591902
# min        24.000000
# 25%        30.000000
# 50%        36.000000
# 75%        43.000000
# max        54.000000
# Name: Employee_Age, dtype: float64

# %%
# Winsorize outliers in the 'Age' column
from scipy.stats.mstats import winsorize
df['Employee_Age'] = winsorize(df['Employee_Age'], limits=[0.05, 0.05])

print(df['Employee_Age'])
# Out:
# 0       41
# 1       49
# 2       37
# 3       33
# 4       27
#         ..
# 1465    36
# 1466    39
# 1467    27
# 1468    49
# 1469    34
# Name: Employee_Age, Length: 1470, dtype: int64
